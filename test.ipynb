# %%
import requests

# %%
url='https://data.epa.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=JSON'

# %%
resp=requests.get(url)

# %%
datas=resp.json()['records']
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '30',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '34',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '74',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '35',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '10',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '1',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '13',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '23',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '39',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '20',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '29',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '44',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '62',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '76',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '48',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '56',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '40',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '36',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '40',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '36',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '42',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '43',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '45',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '27',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '31',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '27',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '28',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '31',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '20',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '27',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '20',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '28',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '30',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '21',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'}]

# %%
len(datas)
# Out:
# 78

# %%
datas[0]
# Out:
# {'site': '大城',
#  'county': '彰化縣',
#  'pm25': '30',
#  'datacreationdate': '2023-04-18 20:00',
#  'itemunit': 'μg/m3'}

# %%
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '30',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '34',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '74',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '35',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '10',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '1',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '13',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '23',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '39',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '20',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '29',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '44',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '62',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '76',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '48',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '56',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '40',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '36',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '40',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '36',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '42',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '43',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '45',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '27',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '46',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '31',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '27',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '28',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '31',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '20',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '27',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '20',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '28',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '30',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '21',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 20:00',
#   'itemunit': 'μg/m3'}]

# %%
columns=list(datas[0].keys())
values=[]
for data in datas:
    values.append(list(data.values()))
    
columns,values
# Out:
# (['site', 'county', 'pm25', 'datacreationdate', 'itemunit'],
#  [['大城', '彰化縣', '30', '2023-04-18 20:00', 'μg/m3'],
#   ['富貴角', '新北市', '17', '2023-04-18 20:00', 'μg/m3'],
#   ['麥寮', '雲林縣', '25', '2023-04-18 20:00', 'μg/m3'],
#   ['關山', '臺東縣', '11', '2023-04-18 20:00', 'μg/m3'],
#   ['馬公', '澎湖縣', '12', '2023-04-18 20:00', 'μg/m3'],
#   ['金門', '金門縣', '9', '2023-04-18 20:00', 'μg/m3'],
#   ['馬祖', '連江縣', '22', '2023-04-18 20:00', 'μg/m3'],
#   ['埔里', '南投縣', '34', '2023-04-18 20:00', 'μg/m3'],
#   ['復興', '高雄市', '11', '2023-04-18 20:00', 'μg/m3'],
#   ['永和', '新北市', '19', '2023-04-18 20:00', 'μg/m3'],
#   ['竹山', '南投縣', '74', '2023-04-18 20:00', 'μg/m3'],
#   ['中壢', '桃園市', '35', '2023-04-18 20:00', 'μg/m3'],
#   ['三重', '新北市', '22', '2023-04-18 20:00', 'μg/m3'],
#   ['冬山', '宜蘭縣', '18', '2023-04-18 20:00', 'μg/m3'],
#   ['宜蘭', '宜蘭縣', '14', '2023-04-18 20:00', 'μg/m3'],
#   ['陽明', '臺北市', '24', '2023-04-18 20:00', 'μg/m3'],
#   ['花蓮', '花蓮縣', '15', '2023-04-18 20:00', 'μg/m3'],
#   ['臺東', '臺東縣', '10', '2023-04-18 20:00', 'μg/m3'],
#   ['恆春', '屏東縣', '1', '2023-04-18 20:00', 'μg/m3'],
#   ['潮州', '屏東縣', '9', '2023-04-18 20:00', 'μg/m3'],
#   ['屏東', '屏東縣', '12', '2023-04-18 20:00', 'μg/m3'],
#   ['小港', '高雄市', '13', '2023-04-18 20:00', 'μg/m3'],
#   ['前鎮', '高雄市', '12', '2023-04-18 20:00', 'μg/m3'],
#   ['前金', '高雄市', '9', '2023-04-18 20:00', 'μg/m3'],
#   ['左營', '高雄市', '11', '2023-04-18 20:00', 'μg/m3'],
#   ['楠梓', '高雄市', '9', '2023-04-18 20:00', 'μg/m3'],
#   ['林園', '高雄市', '11', '2023-04-18 20:00', 'μg/m3'],
#   ['大寮', '高雄市', '23', '2023-04-18 20:00', 'μg/m3'],
#   ['鳳山', '高雄市', '11', '2023-04-18 20:00', 'μg/m3'],
#   ['仁武', '高雄市', '11', '2023-04-18 20:00', 'μg/m3'],
#   ['橋頭', '高雄市', '12', '2023-04-18 20:00', 'μg/m3'],
#   ['美濃', '高雄市', '12', '2023-04-18 20:00', 'μg/m3'],
#   ['臺南', '臺南市', '14', '2023-04-18 20:00', 'μg/m3'],
#   ['安南', '臺南市', '10', '2023-04-18 20:00', 'μg/m3'],
#   ['善化', '臺南市', '15', '2023-04-18 20:00', 'μg/m3'],
#   ['新營', '臺南市', '39', '2023-04-18 20:00', 'μg/m3'],
#   ['嘉義', '嘉義市', '46', '2023-04-18 20:00', 'μg/m3'],
#   ['臺西', '雲林縣', '20', '2023-04-18 20:00', 'μg/m3'],
#   ['朴子', '嘉義縣', '29', '2023-04-18 20:00', 'μg/m3'],
#   ['新港', '嘉義縣', '44', '2023-04-18 20:00', 'μg/m3'],
#   ['崙背', '雲林縣', '62', '2023-04-18 20:00', 'μg/m3'],
#   ['斗六', '雲林縣', '76', '2023-04-18 20:00', 'μg/m3'],
#   ['南投', '南投縣', '46', '2023-04-18 20:00', 'μg/m3'],
#   ['二林', '彰化縣', '48', '2023-04-18 20:00', 'μg/m3'],
#   ['線西', '彰化縣', '56', '2023-04-18 20:00', 'μg/m3'],
#   ['彰化', '彰化縣', '40', '2023-04-18 20:00', 'μg/m3'],
#   ['西屯', '臺中市', '46', '2023-04-18 20:00', 'μg/m3'],
#   ['忠明', '臺中市', '36', '2023-04-18 20:00', 'μg/m3'],
#   ['大里', '臺中市', '40', '2023-04-18 20:00', 'μg/m3'],
#   ['沙鹿', '臺中市', '36', '2023-04-18 20:00', 'μg/m3'],
#   ['豐原', '臺中市', '42', '2023-04-18 20:00', 'μg/m3'],
#   ['三義', '苗栗縣', '43', '2023-04-18 20:00', 'μg/m3'],
#   ['苗栗', '苗栗縣', '45', '2023-04-18 20:00', 'μg/m3'],
#   ['頭份', '苗栗縣', '26', '2023-04-18 20:00', 'μg/m3'],
#   ['新竹', '新竹市', '27', '2023-04-18 20:00', 'μg/m3'],
#   ['竹東', '新竹縣', '46', '2023-04-18 20:00', 'μg/m3'],
#   ['湖口', '新竹縣', '25', '2023-04-18 20:00', 'μg/m3'],
#   ['龍潭', '桃園市', '31', '2023-04-18 20:00', 'μg/m3'],
#   ['平鎮', '桃園市', '22', '2023-04-18 20:00', 'μg/m3'],
#   ['觀音', '桃園市', '27', '2023-04-18 20:00', 'μg/m3'],
#   ['大園', '桃園市', '28', '2023-04-18 20:00', 'μg/m3'],
#   ['桃園', '桃園市', '31', '2023-04-18 20:00', 'μg/m3'],
#   ['大同', '臺北市', '20', '2023-04-18 20:00', 'μg/m3'],
#   ['松山', '臺北市', '15', '2023-04-18 20:00', 'μg/m3'],
#   ['古亭', '臺北市', '19', '2023-04-18 20:00', 'μg/m3'],
#   ['萬華', '臺北市', '27', '2023-04-18 20:00', 'μg/m3'],
#   ['中山', '臺北市', '17', '2023-04-18 20:00', 'μg/m3'],
#   ['士林', '臺北市', '26', '2023-04-18 20:00', 'μg/m3'],
#   ['淡水', '新北市', '24', '2023-04-18 20:00', 'μg/m3'],
#   ['林口', '新北市', '20', '2023-04-18 20:00', 'μg/m3'],
#   ['菜寮', '新北市', '24', '2023-04-18 20:00', 'μg/m3'],
#   ['新莊', '新北市', '28', '2023-04-18 20:00', 'μg/m3'],
#   ['板橋', '新北市', '30', '2023-04-18 20:00', 'μg/m3'],
#   ['土城', '新北市', '26', '2023-04-18 20:00', 'μg/m3'],
#   ['新店', '新北市', '18', '2023-04-18 20:00', 'μg/m3'],
#   ['萬里', '新北市', '21', '2023-04-18 20:00', 'μg/m3'],
#   ['汐止', '新北市', '18', '2023-04-18 20:00', 'μg/m3'],
#   ['基隆', '基隆市', '14', '2023-04-18 20:00', 'μg/m3']])
