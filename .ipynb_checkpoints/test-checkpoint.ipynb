# %%
import requests

# %%
url='https://data.epa.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=JSON'

# %%
resp=requests.get(url)

# %%
datas=resp.json()['records']
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '3',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '28',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '32',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '26',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '0',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '6',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '9',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '7',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '2',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '2',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '7',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '13',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '15',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '26',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '29',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '29',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '28',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '24',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '24',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '23',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '15',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '26',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '30',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '30',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '15',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '6',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '11',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'}]

# %%
len(datas)
# Out:
# 78

# %%
datas[0]
# Out:
# {'site': '大城',
#  'county': '彰化縣',
#  'pm25': '19',
#  'datacreationdate': '2023-05-03 18:00',
#  'itemunit': 'μg/m3'}

# %%
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '3',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '28',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '32',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '26',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '0',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '6',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '9',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '7',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '2',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '2',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '7',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '13',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '15',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '14',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '26',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '29',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '29',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '28',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '24',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '24',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '18',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '23',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '16',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '15',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '26',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '30',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '27',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '30',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '19',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '17',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '20',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '21',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '15',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '22',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '6',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '11',
#   'datacreationdate': '2023-05-03 18:00',
#   'itemunit': 'μg/m3'}]

# %% [markdown]
# ### 建立資料庫
# - 1.創建資料庫
# - 2.建立資料表
# - 3.寫入不重複資料
# - 4.取最新數據

# %%
import sqlite3

# %%
conn=sqlite3.connect('pm25.db')
cursor=conn.cursor()

conn,cursor
# Out:
# (<sqlite3.Connection at 0x1ffa98ce8a0>, <sqlite3.Cursor at 0x1ffa9919b90>)

# %%
datas[0].keys()
# Out:
# dict_keys(['site', 'county', 'pm25', 'datacreationdate', 'itemunit'])

# %%
sqlstr='''
create table if not exists data(
id integer primary key autoincrement,
site text,
county text,
pm25 integer,
datacreationdate datetime,
itemunit text
)


'''
cursor.execute(sqlstr)
conn.commit()

# %% [markdown]
# ### 檢查資料是否存在

# %%
values = []
for data in datas:
    data = list(data.values())
    try:
        data[2] = eval(data[2])
        values.append(data)
    except Exception as e:
        print(e)
values
# Out:
# unexpected EOF while parsing (<string>, line 0)
# [['大城', '彰化縣', 19, '2023-05-03 18:00', 'μg/m3'],
#  ['富貴角', '新北市', 18, '2023-05-03 18:00', 'μg/m3'],
#  ['麥寮', '雲林縣', 27, '2023-05-03 18:00', 'μg/m3'],
#  ['關山', '臺東縣', 3, '2023-05-03 18:00', 'μg/m3'],
#  ['馬公', '澎湖縣', 16, '2023-05-03 18:00', 'μg/m3'],
#  ['金門', '金門縣', 22, '2023-05-03 18:00', 'μg/m3'],
#  ['馬祖', '連江縣', 16, '2023-05-03 18:00', 'μg/m3'],
#  ['埔里', '南投縣', 22, '2023-05-03 18:00', 'μg/m3'],
#  ['復興', '高雄市', 14, '2023-05-03 18:00', 'μg/m3'],
#  ['永和', '新北市', 28, '2023-05-03 18:00', 'μg/m3'],
#  ['竹山', '南投縣', 32, '2023-05-03 18:00', 'μg/m3'],
#  ['中壢', '桃園市', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['三重', '新北市', 26, '2023-05-03 18:00', 'μg/m3'],
#  ['冬山', '宜蘭縣', 0, '2023-05-03 18:00', 'μg/m3'],
#  ['宜蘭', '宜蘭縣', 6, '2023-05-03 18:00', 'μg/m3'],
#  ['陽明', '臺北市', 9, '2023-05-03 18:00', 'μg/m3'],
#  ['花蓮', '花蓮縣', 7, '2023-05-03 18:00', 'μg/m3'],
#  ['臺東', '臺東縣', 2, '2023-05-03 18:00', 'μg/m3'],
#  ['恆春', '屏東縣', 2, '2023-05-03 18:00', 'μg/m3'],
#  ['潮州', '屏東縣', 22, '2023-05-03 18:00', 'μg/m3'],
#  ['小港', '高雄市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['前鎮', '高雄市', 14, '2023-05-03 18:00', 'μg/m3'],
#  ['前金', '高雄市', 19, '2023-05-03 18:00', 'μg/m3'],
#  ['左營', '高雄市', 17, '2023-05-03 18:00', 'μg/m3'],
#  ['楠梓', '高雄市', 14, '2023-05-03 18:00', 'μg/m3'],
#  ['林園', '高雄市', 18, '2023-05-03 18:00', 'μg/m3'],
#  ['大寮', '高雄市', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['鳳山', '高雄市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['仁武', '高雄市', 14, '2023-05-03 18:00', 'μg/m3'],
#  ['橋頭', '高雄市', 17, '2023-05-03 18:00', 'μg/m3'],
#  ['美濃', '高雄市', 17, '2023-05-03 18:00', 'μg/m3'],
#  ['臺南', '臺南市', 18, '2023-05-03 18:00', 'μg/m3'],
#  ['安南', '臺南市', 14, '2023-05-03 18:00', 'μg/m3'],
#  ['善化', '臺南市', 7, '2023-05-03 18:00', 'μg/m3'],
#  ['新營', '臺南市', 13, '2023-05-03 18:00', 'μg/m3'],
#  ['嘉義', '嘉義市', 15, '2023-05-03 18:00', 'μg/m3'],
#  ['臺西', '雲林縣', 16, '2023-05-03 18:00', 'μg/m3'],
#  ['朴子', '嘉義縣', 14, '2023-05-03 18:00', 'μg/m3'],
#  ['新港', '嘉義縣', 27, '2023-05-03 18:00', 'μg/m3'],
#  ['崙背', '雲林縣', 26, '2023-05-03 18:00', 'μg/m3'],
#  ['斗六', '雲林縣', 29, '2023-05-03 18:00', 'μg/m3'],
#  ['南投', '南投縣', 29, '2023-05-03 18:00', 'μg/m3'],
#  ['二林', '彰化縣', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['線西', '彰化縣', 28, '2023-05-03 18:00', 'μg/m3'],
#  ['彰化', '彰化縣', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['西屯', '臺中市', 22, '2023-05-03 18:00', 'μg/m3'],
#  ['忠明', '臺中市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['大里', '臺中市', 24, '2023-05-03 18:00', 'μg/m3'],
#  ['沙鹿', '臺中市', 22, '2023-05-03 18:00', 'μg/m3'],
#  ['豐原', '臺中市', 24, '2023-05-03 18:00', 'μg/m3'],
#  ['三義', '苗栗縣', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['苗栗', '苗栗縣', 19, '2023-05-03 18:00', 'μg/m3'],
#  ['頭份', '苗栗縣', 18, '2023-05-03 18:00', 'μg/m3'],
#  ['新竹', '新竹市', 23, '2023-05-03 18:00', 'μg/m3'],
#  ['竹東', '新竹縣', 19, '2023-05-03 18:00', 'μg/m3'],
#  ['湖口', '新竹縣', 17, '2023-05-03 18:00', 'μg/m3'],
#  ['龍潭', '桃園市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['平鎮', '桃園市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['觀音', '桃園市', 16, '2023-05-03 18:00', 'μg/m3'],
#  ['大園', '桃園市', 27, '2023-05-03 18:00', 'μg/m3'],
#  ['桃園', '桃園市', 15, '2023-05-03 18:00', 'μg/m3'],
#  ['大同', '臺北市', 26, '2023-05-03 18:00', 'μg/m3'],
#  ['松山', '臺北市', 27, '2023-05-03 18:00', 'μg/m3'],
#  ['古亭', '臺北市', 30, '2023-05-03 18:00', 'μg/m3'],
#  ['萬華', '臺北市', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['中山', '臺北市', 27, '2023-05-03 18:00', 'μg/m3'],
#  ['士林', '臺北市', 30, '2023-05-03 18:00', 'μg/m3'],
#  ['淡水', '新北市', 19, '2023-05-03 18:00', 'μg/m3'],
#  ['林口', '新北市', 17, '2023-05-03 18:00', 'μg/m3'],
#  ['菜寮', '新北市', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['新莊', '新北市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['板橋', '新北市', 20, '2023-05-03 18:00', 'μg/m3'],
#  ['土城', '新北市', 21, '2023-05-03 18:00', 'μg/m3'],
#  ['新店', '新北市', 15, '2023-05-03 18:00', 'μg/m3'],
#  ['萬里', '新北市', 22, '2023-05-03 18:00', 'μg/m3'],
#  ['汐止', '新北市', 6, '2023-05-03 18:00', 'μg/m3'],
#  ['基隆', '基隆市', 11, '2023-05-03 18:00', 'μg/m3']]

# %%
sqlstr=f'select * from data where site="{data[0]}" and datacreationdate="{data[-2]}"'
sqlstr
# Out:
# 'select * from data where site="基隆" and datacreationdate="2023-05-03 18:00"'

# %%
list(cursor.execute(sqlstr))
# Out:
# []

# %% [markdown]
# ### 寫入資料

# %%
count=0
for data in datas:
    data = list(data.values())
    try:
        data[2] = eval(data[2])
        sqlstr=f'select * from data where site="{data[0]}" and datacreationdate="{data[-2]}"'
        result=list(cursor.execute(sqlstr))
        if result==[]:
            sqlstr=f'insert into data(site,county,pm25,datacreationdate,itemunit) values("{data[0]}","{data[1]}",\
            "{data[2]}","{data[3]}","{data[4]}")'
            cursor.execute(sqlstr)
            count+=1
    except Exception as e:
        print(e)
    
        
conn.commit()
print(f'更新:{count}筆資料.')
# Out:
# unexpected EOF while parsing (<string>, line 0)
# 更新:77筆資料.

# %% [markdown]
# ### 六都平均值

# %%
import pandas as pd

# %%
df=pd.DataFrame(datas)
df
# Out:
#    site county pm25  datacreationdate itemunit
# 0    大城    彰化縣   19  2023-05-03 18:00    μg/m3
# 1   富貴角    新北市   18  2023-05-03 18:00    μg/m3
# 2    麥寮    雲林縣   27  2023-05-03 18:00    μg/m3
# 3    關山    臺東縣    3  2023-05-03 18:00    μg/m3
# 4    馬公    澎湖縣   16  2023-05-03 18:00    μg/m3
# ..  ...    ...  ...               ...      ...
# 73   土城    新北市   21  2023-05-03 18:00    μg/m3
# 74   新店    新北市   15  2023-05-03 18:00    μg/m3
# 75   萬里    新北市   22  2023-05-03 18:00    μg/m3
# 76   汐止    新北市    6  2023-05-03 18:00    μg/m3
# 77   基隆    基隆市   11  2023-05-03 18:00    μg/m3
#
# [78 rows x 5 columns]

# %%
set(df['county'])
# Out:
# {'南投縣',
#  '嘉義市',
#  '嘉義縣',
#  '基隆市',
#  '宜蘭縣',
#  '屏東縣',
#  '彰化縣',
#  '新北市',
#  '新竹市',
#  '新竹縣',
#  '桃園市',
#  '澎湖縣',
#  '臺中市',
#  '臺北市',
#  '臺南市',
#  '臺東縣',
#  '花蓮縣',
#  '苗栗縣',
#  '連江縣',
#  '金門縣',
#  '雲林縣',
#  '高雄市'}

# %%
six_countys=['臺北市','新北市','桃園市','臺中市','臺南市','高雄市']

# %%
df.groupby('county').get_group(six_countys[2])['pm25'].astype(int).mean()
# Out:
# 19.833333333333332

# %%
six_pm25={}

for county in six_countys:
    six_pm25[county]=round(df.groupby('county').get_group(county)['pm25'].astype(int).mean(),1)
six_pm25
# Out:
# {'臺北市': 24.3, '新北市': 19.4, '桃園市': 19.8, '臺中市': 22.4, '臺南市': 13.0, '高雄市': 17.1}

# %% [markdown]
# ### 每個縣市站點資訊
